# %%
from transformers import AutoTokenizer, RobertaForSequenceClassification, Trainer, TrainingArguments, DataCollatorWithPadding
import pandas as pd
import numpy as np
from datasets import load_dataset, load_metric

MODEL = "klue/roberta-base"
INPUT = "data/sample_train.csv"
MAX_LEN = 256
dataset = load_dataset("csv", data_files=INPUT)['train']
tokenizer = AutoTokenizer.from_pretrained(MODEL)

def example_fn(examples):
    outputs = tokenizer(examples['code1'], examples['code2'], padding=True, max_length=MAX_LEN,truncation=True)
    if 'similar' in examples:
        outputs["labels"] = examples["similar"]
    return outputs

dataset = dataset.map(example_fn, remove_columns=['code1', 'code2', 'similar'])
dataset = dataset.train_test_split(0.1)

_collator = DataCollatorWithPadding(tokenizer=tokenizer)
_metric = load_metric("glue", "sst2")

def metric_fn(p):
    preds, labels = p
    output =  _metric.compute(references=labels, predictions=np.argmax(preds, axis=-1))
    return output
    
model = RobertaForSequenceClassification.from_pretrained(MODEL) # RobertaForSequenceClassification 는 BertForSequenceClassification 와 달리 pooler가 없는게 기본이기 때문에 문장 유사도에 사용 가능.

args = TrainingArguments(
    'runs/',
    per_device_train_batch_size=32,
    num_train_epochs=10,
    do_train=True,
    do_eval=True,
    save_strategy="epoch",
    logging_strategy="epoch",
    evaluation_strategy="epoch",
)

trainer = Trainer(
        model=model,
        args=args,
        data_collator=_collator,
        train_dataset=dataset["train"],
        eval_dataset=dataset["test"],
        tokenizer=tokenizer,
        compute_metrics=metric_fn)

trainer.train()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/sihyun/Downloads/(huggingface)_klue_roberta-base 기반 예측 파이프라인입니다(LB 0.7520)..ipynb Cell 1' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/Users/sihyun/Downloads/%28huggingface%29_klue_roberta-base%20%E1%84%80%E1%85%B5%E1%84%87%E1%85%A1%E1%86%AB%20%E1%84%8B%E1%85%A8%E1%84%8E%E1%85%B3%E1%86%A8%20%E1%84%91%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%91%E1%85%B3%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%86%AB%E1%84%8B%E1%85%B5%E1%86%B8%E1%84%82%E1%85%B5%E1%84%83%E1%85%A1%28LB%200.7520%29..ipynb#ch0000002?line=6'>7</a> INPUT = "data/sample_train.csv"
#       <a href='vscode-notebook-cell:/Users/sihyun/Downloads/%28huggingface%29_klue_roberta-base%20%E1%84%80%E1%85%B5%E1%84%87%E1%85%A1%E1%86%AB%20%E1%84%8B%E1%85%A8%E1%84%8E%E1%85%B3%E1%86%A8%20%E1%84%91%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%91%E1%85%B3%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%86%AB%E1%84%8B%E1%85%B5%E1%86%B8%E1%84%82%E1%85%B5%E1%84%83%E1%85%A1%28LB%200.7520%29..ipynb#ch0000002?line=7'>8</a> MAX_LEN = 256
# ----> <a href='vscode-notebook-cell:/Users/sihyun/Downloads/%28huggingface%29_klue_roberta-base%20%E1%84%80%E1%85%B5%E1%84%87%E1%85%A1%E1%86%AB%20%E1%84%8B%E1%85%A8%E1%84%8E%E1%85%B3%E1%86%A8%20%E1%84%91%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%91%E1%85%B3%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%86%AB%E1%84%8B%E1%85%B5%E1%86%B8%E1%84%82%E1%85%B5%E1%84%83%E1%85%A1%28LB%200.7520%29..ipynb#ch0000002?line=8'>9</a> dataset = load_dataset("csv", data_files=INPUT)['train']
#      <a href='vscode-notebook-cell:/Users/sihyun/Downloads/%28huggingface%29_klue_roberta-base%20%E1%84%80%E1%85%B5%E1%84%87%E1%85%A1%E1%86%AB%20%E1%84%8B%E1%85%A8%E1%84%8E%E1%85%B3%E1%86%A8%20%E1%84%91%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%91%E1%85%B3%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%86%AB%E1%84%8B%E1%85%B5%E1%86%B8%E1%84%82%E1%85%B5%E1%84%83%E1%85%A1%28LB%200.7520%29..ipynb#ch0000002?line=9'>10</a> tokenizer = AutoTokenizer.from_pretrained(MODEL)
#      <a href='vscode-notebook-cell:/Users/sihyun/Downloads/%28huggingface%29_klue_roberta-base%20%E1%84%80%E1%85%B5%E1%84%87%E1%85%A1%E1%86%AB%20%E1%84%8B%E1%85%A8%E1%84%8E%E1%85%B3%E1%86%A8%20%E1%84%91%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%91%E1%85%B3%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%86%AB%E1%84%8B%E1%85%B5%E1%86%B8%E1%84%82%E1%85%B5%E1%84%83%E1%85%A1%28LB%200.7520%29..ipynb#ch0000002?line=11'>12</a> def example_fn(examples):
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py:1664, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, **config_kwargs)
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1660'>1661</a> ignore_verifications = ignore_verifications or save_infos
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1662'>1663</a> # Create a dataset builder
# -> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1663'>1664</a> builder_instance = load_dataset_builder(
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1664'>1665</a>     path=path,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1665'>1666</a>     name=name,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1666'>1667</a>     data_dir=data_dir,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1667'>1668</a>     data_files=data_files,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1668'>1669</a>     cache_dir=cache_dir,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1669'>1670</a>     features=features,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1670'>1671</a>     download_config=download_config,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1671'>1672</a>     download_mode=download_mode,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1672'>1673</a>     revision=revision,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1673'>1674</a>     use_auth_token=use_auth_token,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1674'>1675</a>     **config_kwargs,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1675'>1676</a> )
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1677'>1678</a> # Return iterable dataset in case of streaming
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1678'>1679</a> if streaming:
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py:1490, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, **config_kwargs)
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1487'>1488</a>     download_config = download_config.copy() if download_config else DownloadConfig()
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1488'>1489</a>     download_config.use_auth_token = use_auth_token
# -> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1489'>1490</a> dataset_module = dataset_module_factory(
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1490'>1491</a>     path,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1491'>1492</a>     revision=revision,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1492'>1493</a>     download_config=download_config,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1493'>1494</a>     download_mode=download_mode,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1494'>1495</a>     data_dir=data_dir,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1495'>1496</a>     data_files=data_files,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1496'>1497</a> )
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1498'>1499</a> # Get dataset builder class from the processing script
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1499'>1500</a> builder_cls = import_main_class(dataset_module.module_path)
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py:1150, in dataset_module_factory(path, revision, download_config, download_mode, force_local_path, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1129'>1130</a> # We have several ways to get a dataset builder:
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1130'>1131</a> #
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1131'>1132</a> # - if path is the name of a packaged dataset module
#    (...)
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1146'>1147</a>
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1147'>1148</a> # Try packaged
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1148'>1149</a> if path in _PACKAGED_DATASETS_MODULES:
# -> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1149'>1150</a>     return PackagedDatasetModuleFactory(
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1150'>1151</a>         path,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1151'>1152</a>         data_dir=data_dir,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1152'>1153</a>         data_files=data_files,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1153'>1154</a>         download_config=download_config,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1154'>1155</a>         download_mode=download_mode,
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1155'>1156</a>     ).get_module()
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1156'>1157</a> # Try locally
#    <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=1157'>1158</a> elif path.endswith(filename):
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py:800, in PackagedDatasetModuleFactory.get_module(self)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=793'>794</a> def get_module(self) -> DatasetModule:
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=794'>795</a>     patterns = (
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=795'>796</a>         sanitize_patterns(self.data_files)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=796'>797</a>         if self.data_files is not None
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=797'>798</a>         else get_patterns_locally(str(Path().resolve()))
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=798'>799</a>     )
# --> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=799'>800</a>     data_files = DataFilesDict.from_local_or_remote(patterns, use_auth_token=self.downnload_config.use_auth_token)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=800'>801</a>     module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/load.py?line=801'>802</a>     builder_kwargs = {"hash": hash, "data_files": data_files}
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py:576, in DataFilesDict.from_local_or_remote(cls, patterns, base_path, allowed_extensions, use_auth_token)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=572'>573</a> out = cls()
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=573'>574</a> for key, patterns_for_key in patterns.items():
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=574'>575</a>     out[key] = (
# --> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=575'>576</a>         DataFilesList.from_local_or_remote(
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=576'>577</a>             patterns_for_key,
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=577'>578</a>             base_path=base_path,
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=578'>579</a>             allowed_extensions=allowed_extensions,
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=579'>580</a>             use_auth_token=use_auth_token,
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=580'>581</a>         )
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=581'>582</a>         if not isinstance(patterns_for_key, DataFilesList)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=582'>583</a>         else patterns_for_key
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=583'>584</a>     )
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=584'>585</a> return out
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py:544, in DataFilesList.from_local_or_remote(cls, patterns, base_path, allowed_extensions, use_auth_token)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=534'>535</a> @classmethod
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=535'>536</a> def from_local_or_remote(
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=536'>537</a>     cls,
#    (...)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=540'>541</a>     use_auth_token: Optional[Union[bool, str]] = None,
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=541'>542</a> ) -> "DataFilesList":
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=542'>543</a>     base_path = base_path if base_path is not None else str(Path().resolve())
# --> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=543'>544</a>     data_files = resolve_patterns_locally_or_by_urls(base_path, patterns, allowed_extensions)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=544'>545</a>     origin_metadata = _get_origin_metadata_locally_or_by_urls(data_files, use_auth_token=use_auth_token)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=545'>546</a>     return cls(data_files, origin_metadata)
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py:194, in resolve_patterns_locally_or_by_urls(base_path, patterns, allowed_extensions)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=191'>192</a>         data_files.append(Url(pattern))
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=192'>193</a>     else:
# --> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=193'>194</a>         for path in _resolve_single_pattern_locally(base_path, pattern, allowed_extensions):
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=194'>195</a>             data_files.append(path)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=196'>197</a> if not data_files:
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py:144, in _resolve_single_pattern_locally(base_path, pattern, allowed_extensions)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=141'>142</a>     if allowed_extensions is not None:
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=142'>143</a>         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=143'>144</a>     raise FileNotFoundError(error_msg)
#     <a href='file:///Users/sihyun/miniforge3/envs/tf25/lib/python3.8/site-packages/datasets/data_files.py?line=144'>145</a> return sorted(out)
#
# FileNotFoundError: Unable to find '/Users/sihyun/Downloads/data/sample_train.csv' at /Users/sihyun/Downloads

# %%
import pandas as pd

TEST = "data/test.csv"
SUB = "data/sample_submission.csv"

test_dataset = load_dataset("csv", data_files=TEST)['train']
test_dataset = test_dataset.map(example_fn, remove_columns=['code1', 'code2'])

predictions = trainer.predict(test_dataset)

df = pd.read_csv(SUB)
df['similar'] = np.argmax(predictions.predictions, axis=-1)
df.to_csv('./submissions/submission.csv', index=False)
# Out:
# Using custom data configuration default-119b339a9ccf4b98
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-119b339a9ccf4b98/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset({
#     features: ['pair_id', 'code1', 'code2'],
#     num_rows: 179700
# })
#   0%|          | 0/179700 [00:00<?, ?ex/s]
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: pair_id. If pair_id are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 179700
#   Batch size = 8
#     <div>
#
#       <progress value='22463' max='22463' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [22463/22463 15:57]
#     </div>
